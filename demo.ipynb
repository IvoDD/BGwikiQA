# %%
from sample import AnswerQuestion
aq = AnswerQuestion()
# Out:
# Use device: gpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/home/daninnm/stanfordnlp_resources/bg_btb_models/bg_btb_tokenizer.pt', 'lang': 'bg', 'shorthand': 'bg_btb', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/home/daninnm/stanfordnlp_resources/bg_btb_models/bg_btb_tagger.pt', 'pretrain_path': '/home/daninnm/stanfordnlp_resources/bg_btb_models/bg_btb.pretrain.pt', 'lang': 'bg', 'shorthand': 'bg_btb', 'mode': 'predict'}
# Done loading processors!
# ---
# Started initializing
# Done initializing
# Loading corpus - start
# Loading corpus - end

# %%
titles, answers = aq.query("Кога е създадена България", 3)
for t in titles:
    print(t)
for a in answers:
    print(a)
# Out:
# Started calculating distances
# Done calculating distances
# Българо-американски отношения
# EVN България
# Да, България!
# География на България
# България Ер
# Царство България
# Македонска имиграция в България
# Икономика на България
# Алианц България
# Отношения между Русия и България
# „България ер“ ЕАД е създадена от правителството на Симеон Сакскобургготски през декември 2002 г.
# Производство на енергия от възобновяеми енергийни източнициИстория
# EVN България е създадена след приватизация на енергийните дружества в Пловдив и Стара Загора в началото на 2005 г.
# В България през 2003 година бе създадена национална мрежа на базовите училища, в които се изучава руски език.
# Икономиката или стопанството на България е силно отворена пазарна икономика, на 70-то място в света през 2011 г.
# ...

# %%
titles, answers = aq.query("Къде живеят пингвините", 3)
for t in titles:
    print(t)
for a in answers:
    print(a)
# Out:
# Started calculating distances
# Done calculating distances
# Пингвините от Мадагаскар
# Кратер на пингвините
# Пингвините от Мадагаскар (филм)
# Кайрови
# Скуби-Ду, къде си?
# Списък на глаголическите текстове
# Къде е Маги?
# Къде се крие истината
# Александър Друз
# Йоруба
# Пингвините живеят в зоопарка Сентрал Парк в Ню Йорк и изпълняват различни „паравоенни“ мисии.
# Кратерът на пингвините ( ), наречен още Кратер на Нов Квебек (Cratère du Nouveau-Québec), е кратер в Северна Америка, в далечния север на провинция Квебек, Канада.
# Кайровите живеят в открито море, като отиват на брега единствено по време на размножителния период.
# В него участват девет герои от анимационния филм на студиото DreamWorks Animation „Мадагаскар“ (2005): пингвините Скипър (Том Макграт), Ковалски (Джеф Бенет), Редник (Джеймс Патрик Стюарт) и Рико (Джон Димаджо); лемурите Крал Джулиън (Дани Джейкъбс), Морис (Кевин Майкъл Ричардсън), и Морт (Анди Рихтър); и шимпанзетата Мейсън (Конрад Върнън) и Фил.
# ...

# %%
titles, answers = aq.query("Колко е населението на България", 3)
for t in titles:
    print(t)
for a in answers:
    print(a)
# Out:
# Started calculating distances
# Done calculating distances
# Българо-американски отношения
# Царство България
# България
# Народна република България
# Бургас
# Отношения между Русия и България
# България във Втората световна война
# Аврора (бронепалубен крайцер, 1900)
# Преход на България към демокрация и пазарна икономика
# Население на България
# е много по-разломна за България от 1989 Реалният доход на глава от населението, който намалява прогресивно от средата на 70-те, през 1989 маркира ускорение в спада и минимумът му е достигнат през 1997 г.
# Населението на България към 31 декември 2015 г.
# Населението на България се стопява с 1,8 милиона души.
# png|Процент на българите родени в друга община на България сред общия брой на етническите българи, според преброяването на населението през 1910 г.
# Средната гъстота на населението в България през 2005 г.
# Според Световната банка населението на България през 2012 г.
# ...

# %%
titles, answers = aq.query("Кой е Доналд Тръмп", 3)
for t in titles:
    print(t)
for a in answers:
    print(a)
# Out:
# Started calculating distances
# Done calculating distances
# Доналд Тръмп
# Президентски мандат на Доналд Тръмп
# Trump Organization
# Разследване за импийчмънт на Доналд Тръмп
# Доналд Дък
# Доналд в Матемагическата земя
# Джъд Тръмп
# Иванка Тръмп
# Стив Банън
# Стажантът
# „Ню Йорк Таймс“ издава книгата на Тимъти О'Брайън „Изкуството да бъдеш Доналд“, в която авторът твърди, че Тръмп не е милиардер, а просто мултимилионер – О'Брайън оценява активите му на 250 милиона долара.
# Тя е сред ръководителите на предизборната кампания на Доналд Тръмп в изборите през 2016 г.
# Скоро след построяването на Тръмп Тауър в Манхатън, Доналд Тръмп вече е считан за един от най-популярните богаташи в САЩ.
# Доналд е четвъртото от петте деца на Фред Тръмп – богат строителен предприемач, чието бизнес седалище е в Ню Йорк.
# Доналд Тръмп публично е обявил, че ще се кандидатира за преизбиране на изборите през 2020 година.
# ...
